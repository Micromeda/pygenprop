# %%
from modules.genome_properties_longform_file_parser import parse_genome_property_longform_file
from modules.genome_properties_flat_file_parser import parse_genome_property_file
from modules.genome_properties_results import assign_genome_properties
import json
import pandas as pd

# %%
with open('testing/test_constants/genomeProperties.txt') as genome_property_file:
    properties_tree = parse_genome_property_file(genome_property_file)

# %%
with open('testing/test_constants/LONGFORM_REPORT__C_chlorochromatii_CaD3.txt') as long_form_one:
    with open('testing/test_constants/LONGFORM_REPORT_GENOME_PROPERTIES_C_luteolum_DSM_273.txt') as long_form_two:
        long_form_one_assignments = parse_genome_property_longform_file(long_form_one)
        long_form_two_assignments = parse_genome_property_longform_file(long_form_two)

# %%
name = long_form_one_assignments.pop('name')

# %%
print(name)
# Out:
# LONGFORM_REPORT__C_chlorochromatii_CaD3

# %%
property_assignments = {}
global_step_assignments = {}
for genome_property_id, assignment_data in long_form_one_assignments.items():
    if bool(assignment_data['partial']):
        result = 'PARTIAL'
    else:
        result = 'YES'
    
    property_assignments[genome_property_id] = result
    
    all_step_numbers = set(step.number for step in properties_tree[genome_property_id].steps)
    supported_step_numbers = set(assignment_data['supported_steps'])
    unsupported_steps_numbers = all_step_numbers - supported_step_numbers
    
    current_genome_property_step_assignments = {}
    for step_number in supported_step_numbers:
        current_genome_property_step_assignments[step_number] = True
        
    for step_number in unsupported_steps_numbers:
        current_genome_property_step_assignments[step_number] = False
        
    global_step_assignments[genome_property_id]=current_genome_property_step_assignments

# %%
root = properties_tree.root
genome_property_id = root.id

genome_property_result = assign_genome_properties(properties_tree, property_assignments, global_step_assignments, genome_property_id)

# %%
len(property_assignments)
# Out:
# 575

# %%
len(properties_tree)
# Out:
# 584

# %%
missing = set(properties_tree.genome_properties_dictionary.keys()) - set(property_assignments.keys())

# %%
missing
# Out:
# {'GenProp0047',
#  'GenProp0193',
#  'GenProp0223',
#  'GenProp0290',
#  'GenProp0483',
#  'GenProp0620',
#  'GenProp0732',
#  'GenProp0787',
#  'GenProp0829'}

# %%
leaf_ids = set(leaf.id for leaf in properties_tree.leafs)

# %%
leaf_ids
# Out:
# {'GenProp0001',
#  'GenProp0010',
#  'GenProp0021',
#  'GenProp0023',
#  'GenProp0030',
#  'GenProp0036',
#  'GenProp0037',
#  'GenProp0038',
#  'GenProp0047',
#  'GenProp0048',
#  'GenProp0051',
#  'GenProp0052',
#  'GenProp0053',
#  'GenProp0055',
#  'GenProp0057',
#  'GenProp0058',
#  'GenProp0059',
#  'GenProp0061',
#  'GenProp0109',
#  'GenProp0110',
#  'GenProp0111',
#  'GenProp0114',
#  'GenProp0117',
#  'GenProp0118',
#  'GenProp0119',
#  'GenProp0120',
#  'GenProp0124',
#  'GenProp0127',
#  'GenProp0128',
#  'GenProp0129',
#  'GenProp0130',
#  'GenProp0132',
#  'GenProp0135',
#  'GenProp0136',
#  'GenProp0137',
#  'GenProp0138',
#  'GenProp0139',
#  'GenProp0141',
#  'GenProp0143',
#  'GenProp0146',
#  'GenProp0147',
#  'GenProp0150',
#  'GenProp0151',
#  'GenProp0155',
#  'GenProp0156',
#  'GenProp0159',
#  'GenProp0160',
#  'GenProp0162',
#  'GenProp0163',
#  'GenProp0164',
#  'GenProp0165',
#  'GenProp0166',
#  'GenProp0168',
#  'GenProp0170',
#  'GenProp0171',
#  'GenProp0172',
#  'GenProp0176',
#  'GenProp0178',
#  'GenProp0182',
#  'GenProp0187',
#  'GenProp0188',
#  'GenProp0189',
#  'GenProp0190',
#  'GenProp0191',
#  'GenProp0192',
#  'GenProp0193',
#  'GenProp0198',
#  'GenProp0201',
#  'GenProp0203',
#  'GenProp0207',
#  'GenProp0208',
#  'GenProp0209',
#  'GenProp0213',
#  'GenProp0214',
#  'GenProp0215',
#  'GenProp0216',
#  'GenProp0217',
#  'GenProp0218',
#  'GenProp0220',
#  'GenProp0221',
#  'GenProp0222',
#  'GenProp0223',
#  'GenProp0225',
#  'GenProp0226',
#  'GenProp0231',
#  'GenProp0232',
#  'GenProp0233',
#  'GenProp0236',
#  'GenProp0238',
#  'GenProp0240',
#  'GenProp0244',
#  'GenProp0245',
#  'GenProp0246',
#  'GenProp0250',
#  'GenProp0251',
#  'GenProp0252',
#  'GenProp0253',
#  'GenProp0254',
#  'GenProp0258',
#  'GenProp0259',
#  'GenProp0262',
#  'GenProp0263',
#  'GenProp0264',
#  'GenProp0265',
#  'GenProp0266',
#  'GenProp0268',
#  'GenProp0269',
#  'GenProp0271',
#  'GenProp0272',
#  'GenProp0273',
#  'GenProp0275',
#  'GenProp0277',
#  'GenProp0281',
#  'GenProp0283',
#  'GenProp0288',
#  'GenProp0289',
#  'GenProp0290',
#  'GenProp0291',
#  'GenProp0292',
#  'GenProp0294',
#  'GenProp0295',
#  'GenProp0304',
#  'GenProp0309',
#  'GenProp0310',
#  'GenProp0311',
#  'GenProp0313',
#  'GenProp0314',
#  'GenProp0315',
#  'GenProp0316',
#  'GenProp0317',
#  'GenProp0318',
#  'GenProp0319',
#  'GenProp0320',
#  'GenProp0321',
#  'GenProp0322',
#  'GenProp0323',
#  'GenProp0324',
#  'GenProp0326',
#  'GenProp0455',
#  'GenProp0456',
#  'GenProp0457',
#  'GenProp0458',
#  'GenProp0460',
#  'GenProp0465',
#  'GenProp0466',
#  'GenProp0468',
#  'GenProp0469',
#  'GenProp0470',
#  'GenProp0471',
#  'GenProp0472',
#  'GenProp0473',
#  'GenProp0474',
#  'GenProp0476',
#  'GenProp0478',
#  'GenProp0480',
#  'GenProp0481',
#  'GenProp0483',
#  'GenProp0484',
#  'GenProp0485',
#  'GenProp0487',
#  'GenProp0488',
#  'GenProp0490',
#  'GenProp0491',
#  'GenProp0492',
#  'GenProp0493',
#  'GenProp0494',
#  'GenProp0542',
#  'GenProp0543',
#  'GenProp0562',
#  'GenProp0610',
#  'GenProp0613',
#  'GenProp0614',
#  'GenProp0617',
#  'GenProp0618',
#  'GenProp0620',
#  'GenProp0624',
#  'GenProp0626',
#  'GenProp0629',
#  'GenProp0630',
#  'GenProp0631',
#  'GenProp0632',
#  'GenProp0633',
#  'GenProp0634',
#  'GenProp0636',
#  'GenProp0637',
#  'GenProp0639',
#  'GenProp0640',
#  'GenProp0641',
#  'GenProp0642',
#  'GenProp0648',
#  'GenProp0649',
#  'GenProp0651',
#  'GenProp0652',
#  'GenProp0653',
#  'GenProp0654',
#  'GenProp0655',
#  'GenProp0658',
#  'GenProp0659',
#  'GenProp0660',
#  'GenProp0661',
#  'GenProp0662',
#  'GenProp0663',
#  'GenProp0664',
#  'GenProp0665',
#  'GenProp0666',
#  'GenProp0668',
#  'GenProp0669',
#  'GenProp0670',
#  'GenProp0671',
#  'GenProp0672',
#  'GenProp0673',
#  'GenProp0674',
#  'GenProp0676',
#  'GenProp0677',
#  'GenProp0678',
#  'GenProp0680',
#  'GenProp0682',
#  'GenProp0683',
#  'GenProp0684',
#  'GenProp0685',
#  'GenProp0688',
#  'GenProp0689',
#  'GenProp0692',
#  'GenProp0694',
#  'GenProp0695',
#  'GenProp0696',
#  'GenProp0697',
#  'GenProp0699',
#  'GenProp0701',
#  'GenProp0702',
#  'GenProp0703',
#  'GenProp0704',
#  'GenProp0705',
#  'GenProp0706',
#  'GenProp0707',
#  'GenProp0708',
#  'GenProp0709',
#  'GenProp0711',
#  'GenProp0712',
#  'GenProp0714',
#  'GenProp0715',
#  'GenProp0716',
#  'GenProp0717',
#  'GenProp0718',
#  'GenProp0719',
#  'GenProp0721',
#  'GenProp0722',
#  'GenProp0723',
#  'GenProp0724',
#  'GenProp0726',
#  'GenProp0728',
#  'GenProp0730',
#  'GenProp0732',
#  'GenProp0735',
#  'GenProp0736',
#  'GenProp0737',
#  'GenProp0738',
#  'GenProp0739',
#  'GenProp0740',
#  'GenProp0741',
#  'GenProp0742',
#  'GenProp0743',
#  'GenProp0744',
#  'GenProp0745',
#  'GenProp0746',
#  'GenProp0747',
#  'GenProp0748',
#  'GenProp0749',
#  'GenProp0750',
#  'GenProp0751',
#  'GenProp0752',
#  'GenProp0753',
#  'GenProp0754',
#  'GenProp0756',
#  'GenProp0757',
#  'GenProp0759',
#  'GenProp0764',
#  'GenProp0766',
#  'GenProp0767',
#  'GenProp0768',
#  'GenProp0778',
#  'GenProp0781',
#  'GenProp0786',
#  'GenProp0787',
#  'GenProp0790',
#  'GenProp0792',
#  'GenProp0794',
#  'GenProp0797',
#  'GenProp0798',
#  'GenProp0802',
#  'GenProp0806',
#  'GenProp0809',
#  'GenProp0810',
#  'GenProp0811',
#  'GenProp0813',
#  'GenProp0821',
#  'GenProp0822',
#  'GenProp0828',
#  'GenProp0829',
#  'GenProp0830',
#  'GenProp0834',
#  'GenProp0835',
#  'GenProp0837',
#  'GenProp0839',
#  'GenProp0840',
#  'GenProp0842',
#  'GenProp0845',
#  'GenProp0847',
#  'GenProp0853',
#  'GenProp0854',
#  'GenProp0855',
#  'GenProp0857',
#  'GenProp0858',
#  'GenProp0859',
#  'GenProp0860',
#  'GenProp0861',
#  'GenProp0862',
#  'GenProp0867',
#  'GenProp0871',
#  'GenProp0872',
#  'GenProp0877',
#  'GenProp0878',
#  'GenProp0879',
#  'GenProp0880',
#  'GenProp0881',
#  'GenProp0882',
#  'GenProp0883',
#  'GenProp0885',
#  'GenProp0886',
#  'GenProp0893',
#  'GenProp0894',
#  'GenProp0895',
#  'GenProp0896',
#  'GenProp0898',
#  'GenProp0899',
#  'GenProp0901',
#  'GenProp0902',
#  'GenProp0903',
#  'GenProp0904',
#  'GenProp0905',
#  'GenProp0907',
#  'GenProp0908',
#  'GenProp0909',
#  'GenProp0910',
#  'GenProp0911',
#  'GenProp0914',
#  'GenProp0915',
#  'GenProp0916',
#  'GenProp0917',
#  'GenProp0918',
#  'GenProp0919',
#  'GenProp0920',
#  'GenProp0921',
#  'GenProp0922',
#  'GenProp0927',
#  'GenProp0928',
#  'GenProp0933',
#  'GenProp0934',
#  'GenProp0935',
#  'GenProp0936',
#  'GenProp0938',
#  'GenProp0939',
#  'GenProp0940',
#  'GenProp0941',
#  'GenProp0942',
#  'GenProp0943',
#  'GenProp0944',
#  'GenProp0945',
#  'GenProp0948',
#  'GenProp0950',
#  'GenProp0954',
#  'GenProp0955',
#  'GenProp0956',
#  'GenProp0957',
#  'GenProp0958',
#  'GenProp0961',
#  'GenProp0962',
#  'GenProp0967',
#  'GenProp0977',
#  'GenProp0978',
#  'GenProp0979',
#  'GenProp0980',
#  'GenProp0981',
#  'GenProp0982',
#  'GenProp0983',
#  'GenProp0984',
#  'GenProp0985',
#  'GenProp0987',
#  'GenProp0988',
#  'GenProp0989',
#  'GenProp0991',
#  'GenProp0992',
#  'GenProp0993',
#  'GenProp0996',
#  'GenProp0999',
#  'GenProp1000',
#  'GenProp1002',
#  'GenProp1003',
#  'GenProp1004',
#  'GenProp1005',
#  'GenProp1006',
#  'GenProp1007',
#  'GenProp1009',
#  'GenProp1010',
#  'GenProp1011',
#  'GenProp1012',
#  'GenProp1013',
#  'GenProp1016',
#  'GenProp1017',
#  'GenProp1026',
#  'GenProp1037',
#  'GenProp1052',
#  'GenProp1053',
#  'GenProp1054',
#  'GenProp1055',
#  'GenProp1057',
#  'GenProp1058',
#  'GenProp1060',
#  'GenProp1061',
#  'GenProp1062',
#  'GenProp1063',
#  'GenProp1064',
#  'GenProp1065',
#  'GenProp1069',
#  'GenProp1070',
#  'GenProp1071',
#  'GenProp1072',
#  'GenProp1074',
#  'GenProp1075',
#  'GenProp1076',
#  'GenProp1077',
#  'GenProp1078',
#  'GenProp1079',
#  'GenProp1080',
#  'GenProp1081',
#  'GenProp1082',
#  'GenProp1083',
#  'GenProp1084',
#  'GenProp1085',
#  'GenProp1087',
#  'GenProp1088',
#  'GenProp1089',
#  'GenProp1090',
#  'GenProp1091',
#  'GenProp1092',
#  'GenProp1093',
#  'GenProp1094',
#  'GenProp1095',
#  'GenProp1098',
#  'GenProp1099',
#  'GenProp1100',
#  'GenProp1101',
#  'GenProp1102',
#  'GenProp1103',
#  'GenProp1104',
#  'GenProp2012',
#  'GenProp2017',
#  'GenProp2021'}

# %%
missing - leaf_ids
# Out:
# set()

# %%
genome_property_result
# Out:
# 'PARTIAL'
